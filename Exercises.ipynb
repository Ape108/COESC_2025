# %%
from sklearn.datasets import load_diabetes
import pandas as pd
import numpy as np
diabetes = load_diabetes()
df = pd.DataFrame(data=diabetes.data, columns=diabetes.feature_names)

# %% [raw]
# # Exercise 0: Spam email or not
#
# - email1: "Hii George, This is to inform you that Geek Squad is scheduled for renewal, and an amount of $749.99 will be debited from your account for the next 3 Year. If you wish to continue the service, this email. To cancel or for any inquiries, please team. +1(810)-580-0233 Membership details: Membership name: PC Support Quantity: 1x Support Tenure: 3 Year Payment Method: Direct Debit Renewal Amount: $749.99 TERMS & CONDITIONS: The ! You are receiving this because you are enrolled with Geek Squad, and your membership has . However, if you don't wish to continue with the service or want a of this amount, kindly contact our Billing Support Number at +1(810)-580-0233"
# - email2: "Hi Albert, It's been 58 days since you left - we miss you! Re-activate your service on any of the plans above and get 50% off for the next 3 months using promo code "WELCOMEBACK50" on the Payment page after selecting a plan to activate on. If you need another Starter Kit, just add promo code "ANOTHERONE" during checkout to get it for 50% off!"
# - email3: "The Monthly Billing Statement for your financial account at the University of Missouri-Kansas City has been prepared and is ready to view online. To view the current monthly bill online, please visit pathway.umkc.edu. Students will use their single sign-on (SSO) - the first part of their UMKC e-mail address - and e-mail password to log in."

# %% [markdown]
# # Exercise 1: Basic Data Exploration
# - View the first 10 rows of the dataset.
# - Check the number of rows and columns in the dataset.
# - Get a concise summary of the dataset using a Pandas function.
# - List all the column names in the dataset.

# %%
# Try Here :
print(f"First Ten Rows: \n{df.head(10)}")
print(f"\nShape: {df.shape}")
print(f"\nDescribe: \n{df.describe()}")
print(f"\nInfo: \n{df.info()}")
print(f"\nColumns: \n{df.columns.tolist()}")
# Out:
# First Ten Rows:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5 -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6 -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7  0.063504  0.050680 -0.001895  0.066630  0.090620  0.108914  0.022869
# 8  0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9 -0.070900 -0.044642  0.039062 -0.033214 -0.012577 -0.034508 -0.024993
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# ...

# %% [markdown]
# # Exercise 2: Descriptive Statistics
# - Find the mean, median, and standard deviation of the `bmi` column.
# - Find the minimum and maximum values for the `bp` column.
# - Calculate the sum of all values in the `s1` column.

# %%
# Try Here :
print("BMI")
col = 'bmi'
print(f"Mean: {df[col].mean()}")
print(f"Median: {df[col].median()}")
print(f"Mode: \n{df[col].mode()}")

print("\nBP")
col = 'bp'
print(f"Min: {df[col].min()}")
print(f"Max: {df[col].max()}")

print("\nS1")
col = 's1'
print(f"Sum: {df[col].sum()}")
# Out:
# BMI
# Mean: -8.013951493363262e-16
# Median: -0.00728376620968916
# Mode:
# 0   -0.030996
# 1   -0.024529
# dtype: float64
#
# BP
# Min: -0.112399602060758
# Max: 0.132044217194516
#
# S1
# Sum: -3.9968028886505635e-14

# %% [markdown]
# # Exercise 3: Filtering and Sorting
# - Filter and display rows where `age` is greater than 0.0.
# - Show all rows where `sex` is -0.044642.
# - Sort the DataFrame based on the `bmi` column in descending order.

# %%
# Try Here :
age_filter = df['age'] > 0.0
print(f"Age > 0.0 \n{df[age_filter]}")
sex_filter = df['sex'] == -0.044642
print(f"\nSex == -0.044642 \n{df[sex_filter]}")
print(f"\nSorted by BMI Descending \n{df.sort_values(by='bmi', ascending=False)}")
# Out:
# Age > 0.0
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 7    0.063504  0.050680 -0.001895  0.066630  0.090620  0.108914  0.022869
# 8    0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# ..        ...       ...       ...       ...       ...       ...       ...
# 431  0.070769  0.050680 -0.030996  0.021872 -0.037344 -0.047034  0.033914
# 432  0.009016 -0.044642  0.055229 -0.005671  0.057597  0.044719 -0.002903
# 434  0.016281 -0.044642  0.001339  0.008101  0.005311  0.010899  0.030232
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
#
#            s4        s5        s6
# ...

# %% [markdown]
# # Exercise 4: Indexing and Slicing
# - Select only the `age` and `bp` columns.
# - Select rows 5 to 15 from the dataset.
# - Select the rows where `age` is less than 0.0 and `s5` is greater than 0.0.

# %%
# Try Here :
age_bp_df = df[['age', 'bp']]
print(f"Age and Blood Pressure\n{age_bp_df}")
print(f"\nRows 5-15\n{df.iloc[5:16, :]}")
age_s5_filter = (df['age'] < 0.0) & (df['s5'] > 0.0)
print(f"\nAge < 0.0 and s5 > 0.0\n{df[age_s5_filter]}")
# Out:
# Age and Blood Pressure
#           age        bp
# 0    0.038076  0.021872
# 1   -0.001882 -0.026328
# 2    0.085299 -0.005671
# 3   -0.089063 -0.036656
# 4    0.005383  0.021872
# ..        ...       ...
# 437  0.041708  0.059744
# 438 -0.005515 -0.067642
# 439  0.041708  0.017282
# 440 -0.045472  0.001215
# 441 -0.045472 -0.081414
#
# [442 rows x 2 columns]
#
# Rows 5-15
#          age       sex       bmi        bp        s1        s2        s3  \
# 5  -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6  -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7   0.063504  0.050680 -0.001895  0.066630  0.090620  0.108914  0.022869
# 8   0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9  -0.070900 -0.044642  0.039062 -0.033214 -0.012577 -0.034508 -0.024993
# 10 -0.096328 -0.044642 -0.083808  0.008101 -0.103389 -0.090561 -0.013948
# 11  0.027178  0.050680  0.017506 -0.033214 -0.007073  0.045972 -0.065491
# ...

# %% [markdown]
# # Exercise 5: Grouping and Aggregation
#
# - Group the data by `sex` and find the mean of each feature.
# - Calculate the average `bmi` for each `sex`.
# - Count the number of observations for each `sex`.

# %%
# Try Here :
print(f"Means Grouped by Sex\n{df.groupby('sex').mean()}")
print(f"\nMean BMI Grouped by Sex\n{df.groupby('sex')['bmi'].mean()}")
print(f"Number of Observations By Sex\n{df.groupby('sex').size()}")
# Out:
# Means Grouped by Sex
#                 age       bmi        bp        s1        s2        s3  \
# sex
# -0.044642 -0.007756 -0.003936 -0.010759 -0.001575 -0.006368  0.016923
#  0.050680  0.008805  0.004468  0.012215  0.001788  0.007229 -0.019212
#
#                  s4        s5        s6
# sex
# -0.044642 -0.014826 -0.006693 -0.009291
#  0.050680  0.016832  0.007598  0.010548
#
# Mean BMI Grouped by Sex
# sex
# -0.044642   -0.003936
#  0.050680    0.004468
# Name: bmi, dtype: float64
# Number of Observations By Sex
# sex
# -0.044642    235
#  0.050680    207
# dtype: int64

# %% [markdown]
# # Exercise 6: Handling Missing Data (for Demonstration)
# - Introduce missing values in the `s2` column for the first 10 rows.
# - Check for missing values in each column.
# - Fill missing values in `s2` with the mean of the column.

# %%
# Try Here :
new_df = df.copy()
new_df.loc[1:11, 's2'] = np.nan
print("Null Values")
print(new_df.isnull().sum())
print("\nMissing Data")
print(new_df.iloc[1:16, 0:6])
new_df_filled = new_df.fillna(new_df['s2'].mean())
print("\nFilled Data")
print(new_df_filled.iloc[1:16, 0:6])
# Out:
# Null Values
# age     0
# sex     0
# bmi     0
# bp      0
# s1      0
# s2     11
# s3      0
# s4      0
# s5      0
# s6      0
# dtype: int64
#
# Missing Data
#          age       sex       bmi        bp        s1        s2
# 1  -0.001882 -0.044642 -0.051474 -0.026328 -0.008449       NaN
# 2   0.085299  0.050680  0.044451 -0.005671 -0.045599       NaN
# 3  -0.089063 -0.044642 -0.011595 -0.036656  0.012191       NaN
# 4   0.005383 -0.044642 -0.036385  0.021872  0.003935       NaN
# 5  -0.092695 -0.044642 -0.040696 -0.019442 -0.068991       NaN
# 6  -0.045472  0.050680 -0.047163 -0.015999 -0.040096       NaN
# 7   0.063504  0.050680 -0.001895  0.066630  0.090620       NaN
# 8   0.041708  0.050680  0.061696 -0.040099 -0.013953       NaN
# 9  -0.070900 -0.044642  0.039062 -0.033214 -0.012577       NaN
# 10 -0.096328 -0.044642 -0.083808  0.008101 -0.103389       NaN
# 11  0.027178  0.050680  0.017506 -0.033214 -0.007073       NaN
# ...

# %% [markdown]
# # Classification Exercise

# %%
# Step 1: Import Necessary Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Classifiers
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB

# Step 2: Load the Dataset
cancer = datasets.load_breast_cancer()
X = cancer.data  # Features
y = cancer.target  # Target classes

# Convert to a DataFrame for better visualization (optional)
cancer_df = pd.DataFrame(data=X, columns=cancer.feature_names)
cancer_df['target'] = y

for i in range(2, 5): # Try out different test sizes
    print(f"\ntest_size = {i/10}")
    # Step 3: Split the Dataset into Training and Testing Sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i/10, random_state=1)
    
    # Step 4: Train a Classification Model
    # clf = RandomForestClassifier(n_estimators=100, random_state=42)
    # clf = SVC()
    # clf = KNeighborsClassifier(n_neighbors=5)
    # clf = DecisionTreeClassifier(random_state=42)
    # clf = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
    # clf = GaussianNB()
    clf = LogisticRegression(max_iter=10000, random_state=42)
    clf.fit(X_train, y_train)
    
    # Step 5: Make Predictions
    y_pred = clf.predict(X_test)
    
    # Step 6: Evaluate the Model
    print("Confusion Matrix:")
    print(confusion_matrix(y_test, y_pred))
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred))
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
# Out:
# test_size = 0.2
# Confusion Matrix:
# [[37  5]
#  [ 1 71]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.88      0.93        42
#            1       0.93      0.99      0.96        72
#
#     accuracy                           0.95       114
#    macro avg       0.95      0.93      0.94       114
# weighted avg       0.95      0.95      0.95       114
#
# Accuracy: 0.95
#
# test_size = 0.3
# Confusion Matrix:
# [[ 57   6]
#  [  3 105]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.93        63
#            1       0.95      0.97      0.96       108
#
#     accuracy                           0.95       171
#    macro avg       0.95      0.94      0.94       171
# weighted avg       0.95      0.95      0.95       171
#
# Accuracy: 0.95
#
# test_size = 0.4
# Confusion Matrix:
# [[ 70  10]
#  [  6 142]]
#
# Classification Report:
# ...

# %% [markdown]
# # Classification models
#
# ## Random Forest
# clf = RandomForestClassifier(n_estimators=100, random_state=42)
#
# ## Logistic Regression
# clf = LogisticRegression(max_iter=10000, random_state=42)
#
# ## Support Vector Machine (SVM)
# clf = SVC()
#
# ## K-Nearest Neighbors (KNN)
# clf = KNeighborsClassifier(n_neighbors=5)
#
# ## Decision Tree
# clf = DecisionTreeClassifier(random_state=42)
#
# ## Gradient Boosting
# clf = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
#
# ## Naive Bayes
# clf = GaussianNB()

# %%
# Visualize the results (using the first two features for simplicity)
plt.figure(figsize=(12, 8))

# Plotting true labels
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, marker='o', edgecolor='k', s=100, label='True Labels', alpha=0.5)

# Plotting predicted labels
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_pred, marker='x', edgecolor='red', s=200, label='Predicted Labels', alpha=0.8)

plt.title("Breast Cancer Classification - True vs Predicted Labels (Logistic Regression)")
plt.xlabel(cancer.feature_names[0])  # Mean Radius
plt.ylabel(cancer.feature_names[1])  # Mean Texture
plt.legend()
plt.grid()
plt.xlim(X_test[:, 0].min() - 1, X_test[:, 0].max() + 1)  # Set x limits
plt.ylim(X_test[:, 1].min() - 1, X_test[:, 1].max() + 1)  # Set y limits
plt.show()
